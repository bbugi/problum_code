# %%
list = ["aya", "ye", "woo", "ma"]
list

# %%
list2 = []
for i in range(len(list)):
    print(list[i])
    for j in range(len(list)):
        if list[i] != list[j]:
            print(list[i]+list[j])
        for k in range(len(list)):
            if (list[i] != list[j]) and (list[j] != list[k]) and (list[k] !=list[i]):
                print(list[i]+list[j]+list[k])
            for m in range(len(list)):
                   if (list[i] != list[j]) and (list[i] != list[k]) and (list[i] !=list[m]):
                        if (list[j] != list[k]) and (list[j] != list[m]):
                            if (list[k] != list[m]):
                                print(list[i]+list[j]+list[k]+list[m])

# %%
list2 = []
for i in range(len(list)):
    list2.append(list[i])
    for j in range(len(list)):
        if list[i] != list[j]:
            list2.append(list[i]+list[j])
        for k in range(len(list)):
            if (list[i] != list[j]) and (list[j] != list[k]) and (list[k] !=list[i]):
                list2.append(list[i]+list[j]+list[k])
            for m in range(len(list)):
                   if (list[i] != list[j]) and (list[i] != list[k]) and (list[i] !=list[m]):
                        if (list[j] != list[k]) and (list[j] != list[m]):
                            if (list[k] != list[m]):
                                list2.append(list[i]+list[j]+list[k]+list[m])
list2

# %%
babbling = ["aya", "yee", "u", "maa", "wyeoo"]
babbling2 = ["ayaye", "uuuma", "ye", "yemawoo", "ayaa"]

# %%
answer = 0
for x in babbling:
    if x in list2:
        answer += 1
print(answer)

# %%
answer = 0
for x in babbling2:
    if x in list2:
        answer += 1
print(answer)

# %%
a1 = 'aya'
a2 = 'ye'
a3 = 'woo'
a4 = 'ma'


list = ['aya','ye','woo','ma']

# %%
print(list)
# Out:
# ['aya', 'ye', 'woo', 'ma']

# %%
list[0],list[1],list[2],list[3]
# Out:
# ('aya', 'ye', 'woo', 'ma')

# %%
for i in list:
    print(i)
# Out:
# aya
# ye
# woo
# ma

# %%
join_list = ''.join(list)
join_list
# Out:
# 'ayayewooma'

# %%
for i in range(0,4):
    name = ''.join(list[i])

print(name)
# Out:
# ma

# %%
list2 = []

for i in range(len(list)):
    list2.append(list[i])
    for j in range(i+1, len(list)):
        list2.append(list[i]+list[j])
        list2.append(list[j]+list[i])

        for k in range(j+1, len(list)):
            list2.append(list[i]+list[j]+list[k])
            list2.append(list[i]+list[k]+list[j])
            list2.append(list[j]+list[i]+list[k])
            list2.append(list[j]+list[k]+list[i])
            list2.append(list[k]+list[i]+list[j])
            list2.append(list[k]+list[j]+list[i])

            for m in range(k+1, len(list)):
                list2.append(list[i]+list[j]+list[k]+list[m])
                list2.append(list[i]+list[j]+list[m]+list[k])
                list2.append(list[i]+list[j]+list[m]+list[k])

                list2.append(list[i]+list[j]+list[k]+list[m])
                list2.append(list[i]+list[j]+list[k]+list[m])

# %%
print(list2)
# Out:
# ['aya', 'ayaye', 'yeaya', 'ayayewoo', 'ayayewooma', 'ayayema', 'ayawoo', 'wooaya', 'ayawooma', 'ayama', 'maaya', 'ye', 'yewoo', 'wooye', 'yewooma', 'yema', 'maye', 'woo', 'wooma', 'mawoo', 'ma']

# %%
list
# Out:
# ['aya', 'ye', 'woo', 'ma']

# %%
list[0]
# Out:
# 'aya'

# %%
for i in range(1, len(list)):
    print(list[i])
    for j in range(i+1, len(list)):
        print(list[i]+list[j])
        print(list[j]+list[i])
# Out:
# ye
# yewoo
# wooye
# yema
# maye
# woo
# wooma
# mawoo
# ma

# %%
list2 = []

for i in range(len(list)):
    list2.append(list[i])
    for j in range(i+1, len(list)):
        list2.append(list[i]+list[j])
        list2.append(list[j]+list[i])

        for k in range(j+1, len(list)):
            list2.append(list[i]+list[j]+list[k])
            list2.append(list[i]+list[k]+list[j])
            list2.append(list[j]+list[i]+list[k])
            list2.append(list[j]+list[k]+list[i])
            list2.append(list[k]+list[i]+list[j])
            list2.append(list[k]+list[j]+list[i])

            for m in range(k+1, len(list)):
                list2.append(list[i]+list[j]+list[k]+list[m])
                list2.append(list[i]+list[j]+list[m]+list[k])
                list2.append(list[i]+list[k]+list[j]+list[m])
                list2.append(list[i]+list[k]+list[m]+list[k])

                list2.append(list[i]+list[j]+list[k]+list[m])
                list2.append(list[i]+list[j]+list[m]+list[k])
                list2.append(list[i]+list[k]+list[j]+list[m])
                list2.append(list[i]+list[k]+list[m]+list[k])

                list2.append(list[i]+list[j]+list[k]+list[m])
                list2.append(list[i]+list[j]+list[m]+list[k])
                list2.append(list[i]+list[k]+list[j]+list[m])
                list2.append(list[i]+list[k]+list[m]+list[k])

                list2.append(list[i]+list[j]+list[k]+list[m])
                list2.append(list[i]+list[j]+list[m]+list[k])
                list2.append(list[i]+list[k]+list[j]+list[m])
                list2.append(list[i]+list[k]+list[m]+list[k])
list2
# Out:
# ['aya',
#  'ayaye',
#  'yeaya',
#  'ayayewoo',
#  'ayawooye',
#  'yeayawoo',
#  'yewooaya',
#  'wooayaye',
#  'wooyeaya',
#  'ayayewooma',
#  'ayayema',
#  'ayamaye',
#  'yeayama',
#  'yemaaya',
#  'maayaye',
#  'mayeaya',
#  'ayawoo',
#  'wooaya',
#  'ayawooma',
#  'ayamawoo',
#  'wooayama',
#  'woomaaya',
#  'maayawoo',
#  'mawooaya',
#  'ayama',
#  'maaya',
#  'ye',
#  'yewoo',
#  'wooye',
#  'yewooma',
#  'yemawoo',
#  'wooyema',
#  'woomaye',
#  'mayewoo',
#  'mawooye',
#  'yema',
#  'maye',
#  'woo',
#  'wooma',
#  'mawoo',
#  'ma']

# %%
list2
# Out:
# ['aya',
#  'ayaye',
#  'ayayewoo',
#  'ayayewooma',
#  'ayayema',
#  'ayawoo',
#  'ayawooma',
#  'ayama',
#  'ye',
#  'yewoo',
#  'yewooma',
#  'yema',
#  'woo',
#  'wooma',
#  'ma']
